# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import cluster

# %%
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv('CSV Files/spotify.csv')
data.shape
# Out:
# (18555, 21)

# %%
data.head()
# Out:
#                                 title              artist  \
# 0    See You Again (feat. Kali Uchis)  Tyler, The Creator
# 1      Hall of Fame (feat. will.i.am)          The Script
# 2  Back Where I Belong (feat. Avicii)          Otto Knows
# 3                          Bumpy Ride             Mohombi
# 4       Danza Kuduro (feat. Don Omar)             Lucenzo
#
#                                     uri  features_danceability  \
# 0  spotify:track:7KA4W4McWYRpgf0fWsJZWB                  0.558
# 1  spotify:track:7wMq5n8mYSKlQIGECKUgTX                  0.421
# 2  spotify:track:78W8wiUIlQ2SnWY9TVowKZ                  0.497
# 3  spotify:track:0tBRo4P60DgKmg4jt48upm                  0.709
# 4  spotify:track:1kAZhbcsXqfUjnVeqPywn2                  0.706
#
#    features_energy  features_key  features_loudness  features_mode  \
# 0            0.559           6.0             -9.222            1.0
# 1            0.873          10.0             -4.343            1.0
# 2            0.865           0.0             -3.190            1.0
# 3            0.854           0.0             -4.447            0.0
# 4            0.890           0.0             -6.575            1.0
#
#    features_speechiness  features_acousticness  features_instrumentalness  \
# 0                0.0959                 0.3710                   0.000007
# 1                0.0564                 0.0654                   0.000000
# 2                0.0644                 0.0306                   0.067900
# 3                0.0399                 0.0470                   0.000000
# 4                0.0847                 0.0855                   0.000000
#
#    features_liveness  features_valence  features_tempo   features_type  \
# 0             0.1090             0.620          78.558  audio_features
# 1             0.1230             0.629          84.786  audio_features
# 2             0.4430             0.595         125.960  audio_features
# 3             0.0724             0.826         105.074  audio_features
# 4             0.0465             0.896         130.051  audio_features
#
#               features_id                          features_uri  \
# 0  7KA4W4McWYRpgf0fWsJZWB  spotify:track:7KA4W4McWYRpgf0fWsJZWB
# 1  7wMq5n8mYSKlQIGECKUgTX  spotify:track:7wMq5n8mYSKlQIGECKUgTX
# 2  78W8wiUIlQ2SnWY9TVowKZ  spotify:track:78W8wiUIlQ2SnWY9TVowKZ
# 3  0tBRo4P60DgKmg4jt48upm  spotify:track:0tBRo4P60DgKmg4jt48upm
# 4  1kAZhbcsXqfUjnVeqPywn2  spotify:track:1kAZhbcsXqfUjnVeqPywn2
#
#                                  features_track_href  \
# 0  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 1  https://api.spotify.com/v1/tracks/7wMq5n8mYSKl...
# 2  https://api.spotify.com/v1/tracks/78W8wiUIlQ2S...
# 3  https://api.spotify.com/v1/tracks/0tBRo4P60DgK...
# 4  https://api.spotify.com/v1/tracks/1kAZhbcsXqfU...
#
#                                features_analysis_url  features_duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7KA4...              180387.0
# 1  https://api.spotify.com/v1/audio-analysis/7wMq...              202533.0
# 2  https://api.spotify.com/v1/audio-analysis/78W8...              174203.0
# 3  https://api.spotify.com/v1/audio-analysis/0tBR...              224402.0
# 4  https://api.spotify.com/v1/audio-analysis/1kAZ...              202347.0
#
#    features_time_signature
# 0                      4.0
# 1                      4.0
# 2                      4.0
# 3                      4.0
# 4                      4.0

# %% [markdown]
# #### Dropping Cols

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18555 entries, 0 to 18554
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      18554 non-null  object
#  1   artist                     18555 non-null  object
#  2   uri                        18555 non-null  object
#  3   features_danceability      18554 non-null  float64
#  4   features_energy            18554 non-null  float64
#  5   features_key               18554 non-null  float64
#  6   features_loudness          18554 non-null  float64
#  7   features_mode              18554 non-null  float64
#  8   features_speechiness       18554 non-null  float64
#  9   features_acousticness      18554 non-null  float64
#  10  features_instrumentalness  18554 non-null  float64
#  11  features_liveness          18554 non-null  float64
#  12  features_valence           18554 non-null  float64
#  13  features_tempo             18554 non-null  float64
#  14  features_type              18554 non-null  object
#  15  features_id                18554 non-null  object
#  16  features_uri               18554 non-null  object
#  17  features_track_href        18554 non-null  object
#  18  features_analysis_url      18554 non-null  object
#  19  features_duration_ms       18554 non-null  float64
#  20  features_time_signature    18554 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 3.0+ MB

# %%
data['features_time_signature'].value_counts()
# Out:
# 4.0    17295
# 3.0     1001
# 5.0      161
# 1.0       96
# 0.0        1
# Name: features_time_signature, dtype: int64

# %%
# Dropping unnecessary columns: 
data = data.drop(['features_type', 'features_id','features_uri', 'features_track_href', 'features_analysis_url'], axis=1)

# %%
# remove header prefix
data.columns = data.columns.str.replace("features_", "")

# %%
data.head(1)
# Out:
#                               title              artist  \
# 0  See You Again (feat. Kali Uchis)  Tyler, The Creator
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559  6.0    -9.222
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0959         0.371          0.000007     0.109     0.62
#
#     tempo  duration_ms  time_signature
# 0  78.558     180387.0             4.0

# %% [markdown]
# #### Scaling

# %%
X = data.drop(columns = ['title', 'artist', 'uri'])

# %%
X.describe().T
# Out:
#                     count           mean            std          min  \
# danceability      18554.0       0.585915       0.165983      0.00000
# energy            18554.0       0.629068       0.227950      0.00002
# key               18554.0       5.293629       3.561703      0.00000
# loudness          18554.0      -8.527306       3.892723    -60.00000
# mode              18554.0       0.646761       0.477989      0.00000
# speechiness       18554.0       0.078316       0.081423      0.00000
# acousticness      18554.0       0.274300       0.308013      0.00000
# instrumentalness  18554.0       0.128419       0.272614      0.00000
# liveness          18554.0       0.198341       0.173085      0.00829
# valence           18554.0       0.540253       0.244780      0.00000
# tempo             18554.0     121.268020      28.335085      0.00000
# duration_ms       18554.0  237042.849466  101707.762735  19200.00000
# time_signature    18554.0       3.938989       0.326099      0.00000
#
#                            25%            50%            75%          max
# danceability           0.47400       0.598000       0.706000        0.988
# energy                 0.46800       0.664000       0.815000        1.000
# key                    2.00000       5.000000       9.000000       11.000
# loudness             -10.77900      -7.772000      -5.613000        1.342
# mode                   0.00000       1.000000       1.000000        1.000
# speechiness            0.03460       0.046650       0.080100        0.934
# acousticness           0.02140       0.131000       0.472000        0.996
# instrumentalness       0.00000       0.000164       0.037775        0.993
# liveness               0.09460       0.128000       0.250000        1.000
# valence                0.34700       0.545000       0.739000        1.000
# tempo                 99.87875     120.561000     138.039000      221.764
# duration_ms       181729.25000  219613.000000  267343.500000  2516987.000
# time_signature         4.00000       4.000000       4.000000        5.000

# %% [markdown]
# not sure if duration is going to be importaint? Will keep it around for now. Time signature should be categorical

# %%
scaler = StandardScaler().fit(X)
X_train = pd.DataFrame(scaler.transform(X), columns = X.columns)
X_train.head(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 3>()
#       1 scaler = StandardScaler().fit(X)
#       2 X_train = pd.DataFrame(scaler.transform(X), columns = X.columns)
# ----> 3 export_scaler(scaler)
#       4 X_train.head(4)
#
# NameError: name 'export_scaler' is not defined
